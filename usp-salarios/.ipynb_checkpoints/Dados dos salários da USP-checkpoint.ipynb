# %%
# %pylab inline
import pandas as pd
from IPython import display
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['display']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
dados_usp = pd.read_csv('tabela-nomes_data.csv', sep=';', decimal=',')

# %% [markdown]
# # Valor em bilhões por ano por Categoria

# %%
dc = dados_usp.groupby(dados_usp.Categoria)
anual = dc['Salario Mensal'].sum()*12
anual.plot(kind='barh')

# %% [markdown]
# # Histograma do salário mensal

# %%
dados_usp['Salario Mensal'].hist(bins=20, range=(0,35000))

# %% [markdown]
# #Quantos recebem mais de 35.000?

# %%
dados_usp['Salario Mensal'].hist(bins=20, range=(35000, 65000))

# %%
display.HTML('<H3> {:3d} recebem mais de R$35.000,00 </H3>'.format(len(dados_usp[dados_usp['Salario Mensal'] > 35000])))
# Out:
# <H3>  19 recebem mais de R$35.000,00 </H3>

# %% [markdown]
# # Quem recebe mais de 35.000?

# %%
dados_usp[dados_usp['Salario Mensal'] > 35000][['Nome', 'Unidade da USP', 'Função', 'Categoria', 'Salario Mensal']]
# Out:
#                               Nome  \
# 0         Arrigo Leonardo Angelini
# 1              Sergio de Iudicibus
# 2                     Boris Fausto
# 3          Berta Lange de Morretes
# 4                      Fabio Prado
# 5             Affonso Renato Meira
# 6      Jose Moacyr Vianna Coutinho
# 7     Maria Sylvia Carvalho Franco
# 8          Erwin Theodor Rosenthal
# 9                  Antonio Morales
# 10               Manuel Nunes Dias
# 11   Maria Thereza Schorer Petrone
# 12    Sonia Apparecida de Siqueira
# 13                 Giorgio Moscati
# 14                    Jose Barbosa
# 15               Mario Demar Perez
# 16                  Massaud Moises
# 17                 Lea Goldenstein
# 18  Guilherme da Costa Pinto Filho
#
#                                        Unidade da USP                 Função  \
# 0                             Instituto de Psicologia  Professor Catedratico
# 1   Faculdade de Economia, Administração e Contabi...      Professor Titular
# 2               Reitoria da Universidade de São Paulo             Procurador
# 3                            Instituto de Biociências      Professor Titular
# 4               Reitoria da Universidade de São Paulo             Procurador
# 5                               Faculdade de Medicina      Professor Titular
# 6               Reitoria da Universidade de São Paulo      Professor Titular
# 7   Faculdade de Filosofia, Letras e Ciências Humanas      Professor Titular
# 8   Faculdade de Filosofia, Letras e Ciências Humanas  Professor Catedratico
# 9   Faculdade de Economia, Administração e Contabi...  Professor Catedratico
# 10  Faculdade de Filosofia, Letras e Ciências Humanas      Professor Titular
# 11  Faculdade de Filosofia, Letras e Ciências Humanas      Professor Titular
# 12  Faculdade de Filosofia, Letras e Ciências Humanas      Professor Titular
# 13                                Instituto de Física      Professor Titular
# 14                           Faculdade de Odontologia      Professor Titular
# 15                   Instituto de Ciências Biomédicas      Professor Titular
# 16  Faculdade de Filosofia, Letras e Ciências Humanas      Professor Titular
# 17  Faculdade de Filosofia, Letras e Ciências Humanas      Professor Titular
# 18              Reitoria da Universidade de São Paulo             Procurador
#
#                  Categoria  Salario Mensal
# 0       Docente Aposentado        60248.38
# 1       Docente Aposentado        47422.56
# 2   Funcionário Aposentado        45973.65
# 3       Docente Aposentado        45942.21
# 4   Funcionário Aposentado        45136.16
# 5       Docente Aposentado        42129.90
# 6       Docente Aposentado        42129.90
# 7       Docente Aposentado        42129.90
# 8       Docente Aposentado        41606.39
# 9       Docente Aposentado        40223.76
# 10      Docente Aposentado        40223.76
# 11      Docente Aposentado        40223.76
# 12      Docente Aposentado        40223.76
# 13      Docente Aposentado        39260.04
# 14      Docente Aposentado        38317.60
# 15      Docente Aposentado        37211.63
# 16      Docente Aposentado        37211.63
# 17      Docente Aposentado        35549.21
# 18  Funcionário Aposentado        35211.18

# %% [markdown]
# # Histograma do valor mensal por unidade dos que recebem mais de 35000

# %%
dados_usp[dados_usp['Salario Mensal'] > 35000].groupby(dados_usp['Unidade da USP'])['Salario Mensal'].sum().plot(kind='barh')

# %% [markdown]
# # Histograma do número de pessoas por unidade que recebem mais de 35000

# %%
dados_usp[dados_usp['Salario Mensal'] > 35000].groupby('Unidade da USP')['Salario Mensal'].count()
# Out:
# Unidade da USP
# Faculdade de Economia, Administração e Contabilidade    2
# Faculdade de Filosofia, Letras e Ciências Humanas       7
# Faculdade de Medicina                                   1
# Faculdade de Odontologia                                1
# Instituto de Biociências                                1
# Instituto de Ciências Biomédicas                        1
# Instituto de Física                                     1
# Instituto de Psicologia                                 1
# Reitoria da Universidade de São Paulo                   4
# Name: Salario Mensal, dtype: int64

# %% [markdown]
# # Porcentagem de quantos recebem mais que 24.000

# %%
valor_separador = 24000

total_maior = dados_usp[dados_usp['Salario Mensal'] >= valor_separador]['Salario Mensal'].sum()
num_total_maior = float(len(dados_usp[dados_usp['Salario Mensal'] > valor_separador]))

total_menor = dados_usp[dados_usp['Salario Mensal'] < valor_separador]['Salario Mensal'].sum()
num_total_menor = float(len(dados_usp[dados_usp['Salario Mensal'] < valor_separador]))

total_mes = dados_usp['Salario Mensal'].sum()
num_total_mes = float(len(dados_usp))

# %%
display.HTML('<h2>{:.2%} ({:.0f} de {:.0f}) recebem menos de R${:.2f}, sendo que eles representam {:.2%} do custo da USP em salários.</h2><p> \
              <h2>{:.2%} ({:.0f} de {:.0f}) recebem mais de R${:.2f}, sendo que eles representam {:.2%} do custo da USP em salários.</h2></h2>'\
             .format(total_menor/total_mes,
                     num_total_menor, num_total_mes, valor_separador,\
                     total_menor/total_mes, \
                     num_total_maior/num_total_mes, num_total_maior, num_total_mes, valor_separador, 
                     total_maior/total_mes))
# Out:
# <h2>90.66% (28272 de 29225) recebem menos de R$24000.00, sendo que eles representam 90.66% do custo da USP em salários.</h2><p>               <h2>3.26% (953 de 29225) recebem mais de R$24000.00, , sendo que eles representam 9.34% do custo da USP em salários.</h2></h2>
